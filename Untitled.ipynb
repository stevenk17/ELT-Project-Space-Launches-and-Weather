# %%
import pandas as pd 
from sqlalchemy import create_engine

# %% [markdown]
#  ### Store CSV into DataFrame

# %%
#Import CSV File
csv_file="Resources/SpaceMissions.csv"

#Store CSV File in Dataframe
space_missions_df=pd.read_csv(csv_file)

#Read Dataframe
space_missions_df.head()
# Out:
#   Company Launch Date Launch Time       Launch Site  Temperature (° F)  \
# 0  SpaceX   24-Mar-06       22:30  Marshall Islands               86.0
# 1  SpaceX   21-Mar-07        1:10  Marshall Islands                NaN
# 2  SpaceX    3-Aug-08        3:34  Marshall Islands                NaN
# 3  SpaceX    3-Aug-08        3:34  Marshall Islands                NaN
# 4  SpaceX    3-Aug-08        3:34  Marshall Islands                NaN
#
#    Wind speed (MPH)  Humidity (%) Vehicle Type  Liftoff Thrust (kN)  \
# 0               9.0          74.0     Falcon 1                  343
# 1               NaN           NaN     Falcon 1                  343
# 2               NaN           NaN     Falcon 1                  343
# 3               NaN           NaN     Falcon 1                  343
# 4               NaN           NaN     Falcon 1                  343
#
#    Payload to Orbit (kg)  Rocket Height (m)  Fairing Diameter (m)  \
# ...

# %% [markdown]
# ### Create new data  with selected columsn

# %%
new_space_missions_df=space_missions_df[['Company','Launch Date','Launch Time','Launch Site','Vehicle Type']].copy 

new_space_missions_df.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-fc1bad74fc5d> in <module>
#       1 new_space_missions_df=space_missions_df[['Company','Launch Date','Launch Time','Launch Site','Vehicle Type']].copy
#       2
# ----> 3 new_space_missions_df.type()
#
# AttributeError: 'function' object has no attribute 'type'
