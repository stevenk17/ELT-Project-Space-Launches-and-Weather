# %%
import pandas as pd 
from sqlalchemy import create_engine

# %% [markdown]
#  ### Store CSV into DataFrame

# %%
#Import CSV File
csv_file="Resources/SpaceMissions.csv"

#Store CSV File in Dataframe
space_missions_df=pd.read_csv(csv_file)

#Read Dataframe
space_missions_df.head()
# Out:
#   Company Launch Date Launch Time       Launch Site  Temperature (° F)  \
# 0  SpaceX   24-Mar-06       22:30  Marshall Islands               86.0
# 1  SpaceX   21-Mar-07        1:10  Marshall Islands                NaN
# 2  SpaceX    3-Aug-08        3:34  Marshall Islands                NaN
# 3  SpaceX    3-Aug-08        3:34  Marshall Islands                NaN
# 4  SpaceX    3-Aug-08        3:34  Marshall Islands                NaN
#
#    Wind speed (MPH)  Humidity (%) Vehicle Type  Liftoff Thrust (kN)  \
# 0               9.0          74.0     Falcon 1                  343
# 1               NaN           NaN     Falcon 1                  343
# 2               NaN           NaN     Falcon 1                  343
# 3               NaN           NaN     Falcon 1                  343
# 4               NaN           NaN     Falcon 1                  343
#
#    Payload to Orbit (kg)  Rocket Height (m)  Fairing Diameter (m)  \
# ...

# %% [markdown]
# ### Create new data  with selected column

# %%
new_space_missions_df = space_missions_df[["Company","Launch Date","Launch Time","Launch Site","Vehicle Type"]]

new_space_missions_df.style.highlight_null(null_color='red')
# Out:
# <style  type="text/css" >
#     #T_6a536142_85d9_11ea_ba66_48e244789cdcrow15_col2 {
#             background-color:  red;
#         }    #T_6a536142_85d9_11ea_ba66_48e244789cdcrow18_col2 {
#             background-color:  red;
#         }    #T_6a536142_85d9_11ea_ba66_48e244789cdcrow23_col2 {
#             background-color:  red;
#         }    #T_6a536142_85d9_11ea_ba66_48e244789cdcrow25_col2 {
#             background-color:  red;
#         }</style><table id="T_6a536142_85d9_11ea_ba66_48e244789cdc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Company</th>        <th class="col_heading level0 col1" >Launch Date</th>        <th class="col_heading level0 col2" >Launch Time</th>        <th class="col_heading level0 col3" >Launch Site</th>        <th class="col_heading level0 col4" >Vehicle Type</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
spacemissions_df=new_space_missions_df.rename(columns={"Launch Time":"Launch Time (Min:Sec)"})

spacemissions_df=spacemissions_df.dropna(how="any")

spacemissions_df.head()
# Out:
#   Company Launch Date Launch Time (Min:Sec)       Launch Site Vehicle Type
# 0  SpaceX   24-Mar-06                 22:30  Marshall Islands     Falcon 1
# 1  SpaceX   21-Mar-07                  1:10  Marshall Islands     Falcon 1
# 2  SpaceX    3-Aug-08                  3:34  Marshall Islands     Falcon 1
# 3  SpaceX    3-Aug-08                  3:34  Marshall Islands     Falcon 1
# 4  SpaceX    3-Aug-08                  3:34  Marshall Islands     Falcon 1

# %%
spacemissions_df=df.sort_values(by='Launch Date')

spacemissions_df.style
# Out:
# <style  type="text/css" >
# </style><table id="T_1606d18a_85df_11ea_8fc4_48e244789cdc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Company</th>        <th class="col_heading level0 col1" >Launch Date</th>        <th class="col_heading level0 col2" >Launch Time (Min:Sec)</th>        <th class="col_heading level0 col3" >Launch Site</th>        <th class="col_heading level0 col4" >Vehicle Type</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1606d18a_85df_11ea_8fc4_48e244789cdclevel0_row0" class="row_heading level0 row0" >16</th>
#                         <td id="T_1606d18a_85df_11ea_8fc4_48e244789cdcrow0_col0" class="data row0 col0" >US Air Force</td>
#                         <td id="T_1606d18a_85df_11ea_8fc4_48e244789cdcrow0_col1" class="data row0 col1" >1972-05-20 00:00:00</td>
# ...
